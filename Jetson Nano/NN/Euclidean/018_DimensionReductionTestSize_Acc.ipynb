# %% [markdown]
# ## Experimental results by train & test size using Dimension Reduction
#
# 학습 데이터 및 테스트 사이즈에 따른 실험 결과

# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestCentroid
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.neighbors import KNeighborsClassifier
# Out:
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %% [markdown]
# ## 3D kNN Classification

# %%
train_acc = []
test_acc = []
train_time = []

df = pd.read_csv("../accelerometer.csv")

features = df[["pctid", "x", "y", "z"]].values
target = df["wconfid"].values

feature_names = ["pctid", "x", "y", "z"]
target_names = ["normal", "perpendicular", "opposite"]

pca = PCA(n_components=3)
features = pca.fit(features).transform(features)

# %% [markdown]
# ### Test Size 10%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  137700  / test size :  15300
#
# Training set score: 0.969680
# Test set score: 0.581176
# Training Time : 0.0683 sec

# %% [markdown]
# ### Test Size 20%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  122400  / test size :  30600
#
# Training set score: 0.971846
# Test set score: 0.580131
# Training Time : 0.1834 sec

# %% [markdown]
# ### Test Size 30%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  107100  / test size :  45900
#
# Training set score: 0.974911
# Test set score: 0.579085
# Training Time : 0.2240 sec

# %% [markdown]
# ### Test Size 40%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.4, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  91800  / test size :  61200
#
# Training set score: 0.977919
# Test set score: 0.576127
# Training Time : 0.2132 sec

# %% [markdown]
# ### Test Size 50%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.5, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  76500  / test size :  76500
#
# Training set score: 0.981542
# Test set score: 0.573059
# Training Time : 0.3092 sec

# %% [markdown]
# ### Test Size 60%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.6, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  61200  / test size :  91800
#
# Training set score: 0.984967
# Test set score: 0.571078
# Training Time : 0.4272 sec

# %% [markdown]
# ### Test Size 70%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.7, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  45900  / test size :  107100
#
# Training set score: 0.988911
# Test set score: 0.566004
# Training Time : 0.3420 sec

# %% [markdown]
# ### Test Size 80%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.8, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  30600  / test size :  122400
#
# Training set score: 0.992451
# Test set score: 0.563031
# Training Time : 0.5977 sec

# %% [markdown]
# ### Test Size 90%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.9, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  15300  / test size :  137700
#
# Training set score: 0.996013
# Test set score: 0.557959
# Training Time : 0.5690 sec

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Test Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 10), train_acc, label='TRAIN set')
line2 = ax1.plot(range(1, 10), test_acc, label='TEST set')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line3 = ax2.plot(range(1, 10), train_time, label='TRAIN time', color='green')

lines = line1 + line2 + line3

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()

# %% [markdown]
# ## 2D kNN Classification

# %%
train_acc = []
test_acc = []
train_time = []

df = pd.read_csv("../accelerometer.csv")

features = df[["pctid", "x", "y", "z"]].values
target = df["wconfid"].values

feature_names = ["pctid", "x", "y", "z"]
target_names = ["normal", "perpendicular", "opposite"]

pca = PCA(n_components=2)
features = pca.fit(features).transform(features)
target = target

# %% [markdown]
# ### Test Size 10%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  137700  / test size :  15300
#
# Training set score: 0.969942
# Test set score: 0.504118
# Training Time : 0.0346 sec

# %% [markdown]
# ### Test Size 20%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  122400  / test size :  30600
#
# Training set score: 0.972026
# Test set score: 0.496438
# Training Time : 0.1069 sec

# %% [markdown]
# ### Test Size 30%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  107100  / test size :  45900
#
# Training set score: 0.974827
# Test set score: 0.489564
# Training Time : 0.1587 sec

# %% [markdown]
# ### Test Size 40%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.4, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  91800  / test size :  61200
#
# Training set score: 0.977963
# Test set score: 0.485523
# Training Time : 0.1505 sec

# %% [markdown]
# ### Test Size 50%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.5, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  76500  / test size :  76500
#
# Training set score: 0.981542
# Test set score: 0.479268
# Training Time : 0.1775 sec

# %% [markdown]
# ### Test Size 60%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.6, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  61200  / test size :  91800
#
# Training set score: 0.985000
# Test set score: 0.471590
# Training Time : 0.2597 sec

# %% [markdown]
# ### Test Size 70%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.7, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  45900  / test size :  107100
#
# Training set score: 0.988758
# Test set score: 0.465509
# Training Time : 0.3282 sec

# %% [markdown]
# ### Test Size 80%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.8, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  30600  / test size :  122400
#
# Training set score: 0.992451
# Test set score: 0.457288
# Training Time : 0.3388 sec

# %% [markdown]
# ### Test Size 90%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.9, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  15300  / test size :  137700
#
# Training set score: 0.996013
# Test set score: 0.452237
# Training Time : 0.4654 sec

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Test Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 10), train_acc, label='TRAIN set')
line2 = ax1.plot(range(1, 10), test_acc, label='TEST set')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line3 = ax2.plot(range(1, 10), train_time, label='TRAIN time', color='green')

lines = line1 + line2 + line3

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()

# %% [markdown]
# ## Nearest Centroid Classifier

# %%
train_acc = []
test_acc = []
train_time = []

df = pd.read_csv("../accelerometer.csv")

features = df[["pctid", "x", "y", "z"]].values
target = df["wconfid"].values

feature_names = ["pctid", "x", "y", "z"]
target_names = ["normal", "perpendicular", "opposite"]

# %% [markdown]
# ### Test Size 10%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  137700  / test size :  15300
#
# Training set score: 0.332142
# Test set score: 0.330000
# Training Time : 0.0016 sec

# %% [markdown]
# ### Test Size 20%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  122400  / test size :  30600
#
# Training set score: 0.338047
# Test set score: 0.335588
# Training Time : 0.0023 sec

# %% [markdown]
# ### Test Size 30%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  107100  / test size :  45900
#
# Training set score: 0.334902
# Test set score: 0.330501
# Training Time : 0.0038 sec

# %% [markdown]
# ### Test Size 40%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.4, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  91800  / test size :  61200
#
# Training set score: 0.333878
# Test set score: 0.330915
# Training Time : 0.0052 sec

# %% [markdown]
# ### Test Size 50%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.5, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  76500  / test size :  76500
#
# Training set score: 0.337163
# Test set score: 0.332863
# Training Time : 0.0065 sec

# %% [markdown]
# ### Test Size 60%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.6, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  61200  / test size :  91800
#
# Training set score: 0.338954
# Test set score: 0.337211
# Training Time : 0.0065 sec

# %% [markdown]
# ### Test Size 70%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.7, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  45900  / test size :  107100
#
# Training set score: 0.334684
# Test set score: 0.332754
# Training Time : 0.0075 sec

# %% [markdown]
# ### Test Size 80%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.8, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  30600  / test size :  122400
#
# Training set score: 0.336699
# Test set score: 0.334469
# Training Time : 0.0092 sec

# %% [markdown]
# ### Test Size 90%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.9, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  15300  / test size :  137700
#
# Training set score: 0.338301
# Test set score: 0.332781
# Training Time : 0.0106 sec

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Test Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 10), train_acc, label='TRAIN set')
line2 = ax1.plot(range(1, 10), test_acc, label='TEST set')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line3 = ax2.plot(range(1, 10), train_time, label='TRAIN time', color='green')

lines = line1 + line2 + line3

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()
