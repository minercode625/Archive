# %% [markdown]
# ## Experimental results by train & test size using Dimension Reduction
#
# 학습 데이터 및 테스트 사이즈에 따른 실험 결과

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestCentroid
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## 3D kNN Classification

# %%
train_acc = []
test_acc = []
train_time = []

df = pd.read_csv("../accelerometer.csv")

features = df[["pctid", "x", "y", "z"]].values
target = df["wconfid"].values

feature_names = ["pctid", "x", "y", "z"]
target_names = ["normal", "perpendicular", "opposite"]

pca = PCA(n_components=3)
features = pca.fit(features).transform(features)

# %% [markdown]
# ### Test Size 10%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  137700  / test size :  15300
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-4d1e9ad91af6> in <module>
#      11 knn.fit(x_train, y_train)
#      12
# ---> 13 train_score = knn.score(x_train, y_train)
#      14
#      15 start = time.perf_counter()
#
# ~\Anaconda3\envs\lab\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     649         from .metrics import accuracy_score
#     650
# --> 651         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     652
#     653     def _more_tags(self):
#
# ~\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
#     212             Class labels for each data sample.
#     213         """
# --> 214         neigh_dist, neigh_ind = self.kneighbors(X)
#     215         classes_ = self.classes_
#     216         _y = self._y
#
# ~\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     774             else:
#     775                 parallel_kwargs = {"prefer": "threads"}
# --> 776             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     777                 delayed(_tree_query_parallel_helper)(
#     778                     self._tree, X[s], n_neighbors, return_distance
#
# ~\Anaconda3\envs\lab\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# ~\Anaconda3\envs\lab\lib\site-packages\joblib\parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# ~\Anaconda3\envs\lab\lib\multiprocessing\pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~\Anaconda3\envs\lab\lib\multiprocessing\pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~\Anaconda3\envs\lab\lib\threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~\Anaconda3\envs\lab\lib\threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Test Size 20%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  122400  / test size :  30600
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.366936
# Test set score: 0.342157
# Training Time : 2.4859 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 30%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  107100  / test size :  45900
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.362596
# Test set score: 0.339303
# Training Time : 3.9905 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 40%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.4, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  91800  / test size :  61200
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.348388
# Test set score: 0.341536
# Training Time : 2.7824 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 50%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.5, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  76500  / test size :  76500
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.346510
# Test set score: 0.333712
# Training Time : 2.8301 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 60%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.6, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  61200  / test size :  91800
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.336846
# Test set score: 0.333617
# Training Time : 6.1460 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 70%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.7, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  45900  / test size :  107100
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.334749
# Test set score: 0.333371
# Training Time : 3.1301 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 80%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.8, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  30600  / test size :  122400
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.338137
# Test set score: 0.333031
# Training Time : 7.1107 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 90%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.9, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  15300  / test size :  137700
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.437059
# Test set score: 0.368243
# Training Time : 10.7906 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Test Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 10), train_acc, label='TRAIN set')
line2 = ax1.plot(range(1, 10), test_acc, label='TEST set')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line3 = ax2.plot(range(1, 10), train_time, label='TRAIN time', color='green')

lines = line1 + line2 + line3

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()

# %% [markdown]
# ## 2D kNN Classification

# %%
train_acc = []
test_acc = []
train_time = []

df = pd.read_csv("../accelerometer.csv")

features = df[["pctid", "x", "y", "z"]].values
target = df["wconfid"].values

feature_names = ["pctid", "x", "y", "z"]
target_names = ["normal", "perpendicular", "opposite"]

pca = PCA(n_components=2)
features = pca.fit(features).transform(features)
target = target

# %% [markdown]
# ### Test Size 10%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  137700  / test size :  15300
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.434793
# Test set score: 0.363791
# Training Time : 0.4592 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 20%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  122400  / test size :  30600
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.633783
# Test set score: 0.393268
# Training Time : 1.6710 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 30%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  107100  / test size :  45900
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.407731
# Test set score: 0.341111
# Training Time : 0.9200 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 40%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.4, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  91800  / test size :  61200
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.405675
# Test set score: 0.356111
# Training Time : 1.6629 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 50%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.5, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  76500  / test size :  76500
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.391059
# Test set score: 0.349294
# Training Time : 1.4680 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 60%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.6, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  61200  / test size :  91800
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.397631
# Test set score: 0.342800
# Training Time : 1.7335 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 70%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.7, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  45900  / test size :  107100
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.401111
# Test set score: 0.348711
# Training Time : 2.1271 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 80%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.8, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  30600  / test size :  122400
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.578856
# Test set score: 0.370711
# Training Time : 4.8608 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Test Size 90%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.9, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

knn = KNeighborsClassifier(k, weights='distance', metric='mahalanobis', metric_params={'V': np.cov(x_train, rowvar=False)}, n_jobs=-1)
knn.fit(x_train, y_train)

train_score = knn.score(x_train, y_train)

start = time.perf_counter()
test_score = knn.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % end, "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(knn, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  15300  / test size :  137700
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)
# Training set score: 0.628039
# Test set score: 0.372317
# Training Time : 5.1368 sec
# C:\Users\LAB\Anaconda3\envs\lab\lib\site-packages\sklearn\neighbors\_base.py:600: RuntimeWarning: invalid value encountered in sqrt
#   return tree.query(*args, **kwargs)

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Test Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 10), train_acc, label='TRAIN set')
line2 = ax1.plot(range(1, 10), test_acc, label='TEST set')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line3 = ax2.plot(range(1, 10), train_time, label='TRAIN time', color='green')

lines = line1 + line2 + line3

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()

# %% [markdown]
# ## Nearest Centroid Classifier

# %%
train_acc = []
test_acc = []
train_time = []

df = pd.read_csv("../accelerometer.csv")

features = df[["pctid", "x", "y", "z"]].values
target = df["wconfid"].values

feature_names = ["pctid", "x", "y", "z"]
target_names = ["normal", "perpendicular", "opposite"]

# %% [markdown]
# ### Test Size 10%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  137700  / test size :  15300
#
# Training set score: 0.332142
# Test set score: 0.330000
# Training Time : 0.0015 sec

# %% [markdown]
# ### Test Size 20%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  122400  / test size :  30600
#
# Training set score: 0.338047
# Test set score: 0.335588
# Training Time : 0.0026 sec

# %% [markdown]
# ### Test Size 30%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  107100  / test size :  45900
#
# Training set score: 0.334902
# Test set score: 0.330501
# Training Time : 0.0037 sec

# %% [markdown]
# ### Test Size 40%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.4, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  91800  / test size :  61200
#
# Training set score: 0.333878
# Test set score: 0.330915
# Training Time : 0.0049 sec

# %% [markdown]
# ### Test Size 50%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.5, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  76500  / test size :  76500
#
# Training set score: 0.337163
# Test set score: 0.332863
# Training Time : 0.0062 sec

# %% [markdown]
# ### Test Size 60%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.6, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  61200  / test size :  91800
#
# Training set score: 0.338954
# Test set score: 0.337211
# Training Time : 0.0069 sec

# %% [markdown]
# ### Test Size 70%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.7, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  45900  / test size :  107100
#
# Training set score: 0.334684
# Test set score: 0.332754
# Training Time : 0.0089 sec

# %% [markdown]
# ### Test Size 80%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.8, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  30600  / test size :  122400
#
# Training set score: 0.336699
# Test set score: 0.334469
# Training Time : 0.0088 sec

# %% [markdown]
# ### Test Size 90%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.9, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  15300  / test size :  137700
#
# Training set score: 0.338301
# Test set score: 0.332781
# Training Time : 0.0162 sec

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Test Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 10), train_acc, label='TRAIN set')
line2 = ax1.plot(range(1, 10), test_acc, label='TEST set')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line3 = ax2.plot(range(1, 10), train_time, label='TRAIN time', color='green')

lines = line1 + line2 + line3

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()
