# %% [markdown]
# ## Experimental results by train & test size using Dimension Reduction
#
# 학습 데이터 및 테스트 사이즈에 따른 실험 결과
#
# <span style="color: #2D3748; background-color:#fff5b1;">테스트 사이즈가 점점 증가하고 학습 데이터가 점점 감소하는 경우 정확도는 감소한다. 하지만 분류 시간의 경우 학습 데이터와 테스트 데이터의 비율에 따라 증가하다가 감소한다. PCA를 적용하지 않은 방법과 유사한 형태의 실험 결과를 보여준다.</span>

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## k-Means with PCA feature 3

# %%
total_acc = []
total_time = []

features, target = make_classification(n_samples=15000, n_features=4, n_informative=4, n_redundant=0, n_classes=3, n_clusters_per_class=1, random_state=0)

pca = PCA(n_components=3)
features = pca.fit(features).transform(features)
target_names = ["0", "1", "2"]

# %% [markdown]
# ### Dataset Size 10%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.1, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  1500

# %% [markdown]
# ### Dataset Size 20%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.2, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  3000

# %% [markdown]
# ### Dataset Size 30%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.3, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  4500

# %% [markdown]
# ### Dataset Size 40%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.4, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  6000

# %% [markdown]
# ### Dataset Size 50%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.5, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  7500

# %% [markdown]
# ### Dataset Size 60%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.6, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  9000

# %% [markdown]
# ### Dataset Size 70%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.7, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  10500

# %% [markdown]
# ### Dataset Size 80%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.8, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  12000

# %% [markdown]
# ### Dataset Size 90%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.9, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  13500

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Dataset Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 10), total_acc, label='TEST set', color='red')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line2 = ax2.plot(range(1, 10), total_time, label='TRAIN time', color='green')

lines = line1 + line2

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()

# %% [markdown]
# ## k-Means with PCA feature 2

# %%
total_acc = []
total_time = []

features, target = make_classification(n_samples=15000, n_features=4, n_informative=4, n_redundant=0, n_classes=3, n_clusters_per_class=1, random_state=0)

pca = PCA(n_components=2)
features = pca.fit(features).transform(features)
target_names = ["0", "1", "2"]

# %% [markdown]
# ### Dataset Size 10%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.1, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  1500

# %% [markdown]
# ### Dataset Size 20%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.2, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  3000

# %% [markdown]
# ### Dataset Size 30%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.3, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  4500

# %% [markdown]
# ### Dataset Size 40%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.4, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  6000

# %% [markdown]
# ### Dataset Size 50%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.5, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  7500

# %% [markdown]
# ### Dataset Size 60%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.6, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  9000

# %% [markdown]
# ### Dataset Size 70%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.7, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  10500

# %% [markdown]
# ### Dataset Size 80%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.8, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  12000

# %% [markdown]
# ### Dataset Size 90%

# %%
max_seed = 10

avg_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, _, y_train, _ = train_test_split(features, target, train_size=0.9, random_state=seed, shuffle=True)

    k = 3

    k_means = KMeans(n_clusters=k, random_state=seed)
    start = time.perf_counter()
    k_means.fit(x_train, y_train)
    end = time.perf_counter() - start

    predict = k_means.labels_
    score = metrics.accuracy_score(y_train, k_means.labels_)

    predict_list.extend(predict)
    label_list.extend(y_train)

    avg_acc.append(score)
    avg_time.append(end)

print("Train size : ", len(y_train))
acc_avg = np.array(avg_acc).mean()
time_avg = np.array(avg_time).mean()

total_acc.append(acc_avg)
total_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  13500

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Dataset Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 10), total_acc, label='TEST set', color='red')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line2 = ax2.plot(range(1, 10), total_time, label='TRAIN time', color='green')

lines = line1 + line2

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()
