# %% [markdown]
# ## Experimental results by train & test size using Dimension Reduction
#
# 학습 데이터 및 테스트 사이즈에 따른 실험 결과
#
# <span style="color: #2D3748; background-color:#fff5b1;">테스트 사이즈가 점점 증가하고 학습 데이터가 점점 감소하는 경우 정확도는 감소한다. 하지만 분류 시간의 경우 학습 데이터와 테스트 데이터의 비율에 따라 증가하다가 감소한다. PCA를 적용하지 않은 방법과 유사한 형태의 실험 결과를 보여준다.</span>

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn.datasets import load_wine
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## DBSCAN with PCA feature 3

# %%
total_acc = []
total_time = []

wine = load_wine()

pca = PCA(n_components=3)
features = pca.fit(wine.data).transform(wine.data)
scaler = MinMaxScaler()
features = scaler.fit_transform(features)

target = wine.target
target_names = wine.target_names.tolist()
target_names = target_names + ['outlier']

# %% [markdown]
# ### Dataset Size 10%

# %%
epsilon = 0.3
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.1, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
print(acc)
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  17
# 0.23529411764705882

# %% [markdown]
# ### Dataset Size 20%

# %%
epsilon = 0.4
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.2, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
print(acc)
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  35
# 0.2571428571428571

# %% [markdown]
# ### Dataset Size 30%

# %%
epsilon = 0.2
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.3, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  53

# %% [markdown]
# ### Dataset Size 40%

# %%
epsilon = 0.2
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.4, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  71

# %% [markdown]
# ### Dataset Size 50%

# %%
epsilon = 0.3
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.5, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  89

# %% [markdown]
# ### Dataset Size 60%

# %%
epsilon = 0.3
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.6, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  106

# %% [markdown]
# ### Dataset Size 70%

# %%
epsilon = 0.3
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.7, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  124

# %% [markdown]
# ### Dataset Size 80%

# %%
epsilon = 0.3
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.8, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  142

# %% [markdown]
# ### Dataset Size 90%

# %%
epsilon = 0.3
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.9, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  160

# %% [markdown]
# ### Dataset Size 100%

# %%
epsilon = 0.3
point = 10

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(features, target)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(target, db.labels_)

print("Train size : ", len(target))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(target, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(target, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  178

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Dataset Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 11), total_acc, label='TEST set', color='red')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line2 = ax2.plot(range(1, 11), total_time, label='TRAIN time', color='green')

lines = line1 + line2

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()

# %% [markdown]
# ## DBSCAN with PCA feature 2

# %%
total_acc = []
total_time = []

wine = load_wine()

pca = PCA(n_components=2)
features = pca.fit(wine.data).transform(wine.data)
features = scaler.fit_transform(features)
target = wine.target
target_names = wine.target_names.tolist()
target_names = target_names + ['outlier']

# %% [markdown]
# ### Dataset Size 10%

# %%
epsilon = 0.2
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.1, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  17

# %% [markdown]
# ### Dataset Size 20%

# %%
epsilon = 0.3
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.2, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  35

# %% [markdown]
# ### Dataset Size 30%

# %%
epsilon = 0.1
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.3, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  53

# %% [markdown]
# ### Dataset Size 40%

# %%
epsilon = 0.1
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.4, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  71

# %% [markdown]
# ### Dataset Size 50%

# %%
epsilon = 0.2
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.5, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  89

# %% [markdown]
# ### Dataset Size 60%

# %%
epsilon = 0.2
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.6, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  106

# %% [markdown]
# ### Dataset Size 70%

# %%
epsilon = 0.2
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.7, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  124

# %% [markdown]
# ### Dataset Size 80%

# %%
epsilon = 0.2
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.8, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  142

# %% [markdown]
# ### Dataset Size 90%

# %%
epsilon = 0.2
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.9, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  160

# %% [markdown]
# ### Dataset Size 100%

# %%
epsilon = 0.2
point = 10

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(features, target)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(target, db.labels_)

print("Train size : ", len(target))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(target, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(target, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  178

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Dataset Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 11), total_acc, label='TEST set', color='red')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line2 = ax2.plot(range(1, 11), total_time, label='TRAIN time', color='green')

lines = line1 + line2

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()
