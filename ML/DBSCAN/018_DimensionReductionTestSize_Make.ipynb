# %% [markdown]
# ## Experimental results by train & test size using Dimension Reduction
#
# 학습 데이터 및 테스트 사이즈에 따른 실험 결과
#
# <span style="color: #2D3748; background-color:#fff5b1;">테스트 사이즈가 점점 증가하고 학습 데이터가 점점 감소하는 경우 정확도는 감소한다. 하지만 분류 시간의 경우 학습 데이터와 테스트 데이터의 비율에 따라 증가하다가 감소한다. PCA를 적용하지 않은 방법과 유사한 형태의 실험 결과를 보여준다.</span>

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## DBSCAN with PCA feature 3

# %%
total_acc = []
total_time = []

features, target = make_classification(n_samples=15000, n_features=4, n_informative=4, n_redundant=0, n_classes=3, n_clusters_per_class=1, random_state=0)
scaler = MinMaxScaler()
features = scaler.fit_transform(features)

pca = PCA(n_components=3)
features = pca.fit(features).transform(features)
target_names = ["0", "1", "2", "outlier"]

# %% [markdown]
# ### Dataset Size 10%

# %%
epsilon = 0.1
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.1, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
print(acc)
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  1500
# 0.36133333333333334
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-94e5fdded84b> in <module>
#      22 cm = confusion_matrix(y_train, predict, normalize="true")
#      23 disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
# ---> 24 disp.plot(cmap=plt.cm.Blues)
#      25
#      26 cm = confusion_matrix(y_train, predict)
#
# ~\Anaconda3\envs\lab\lib\site-packages\sklearn\metrics\_plot\confusion_matrix.py in plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar)
#     161         if colorbar:
#     162             fig.colorbar(self.im_, ax=ax)
# --> 163         ax.set(
#     164             xticks=np.arange(n_classes),
#     165             yticks=np.arange(n_classes),
#
# ~\Anaconda3\envs\lab\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1111         if move_color_to_start:
#    1112             kwargs = {"color": kwargs.pop("color"), **kwargs}
# -> 1113         return self.update(kwargs)
#    1114
#    1115     def findobj(self, match=None, include_self=True):
#
# ~\Anaconda3\envs\lab\lib\site-packages\matplotlib\artist.py in update(self, props)
#     996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
# --> 998                     ret.append(func(v))
#     999         if ret:
#    1000             self.pchanged()
#
# ~\Anaconda3\envs\lab\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# ~\Anaconda3\envs\lab\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~\Anaconda3\envs\lab\lib\site-packages\matplotlib\axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1791         if fontdict is not None:
#    1792             kwargs.update(fontdict)
# -> 1793         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1794
#    1795     @cbook._make_keyword_only("3.2", "minor")
#
# ~\Anaconda3\envs\lab\lib\site-packages\matplotlib\axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1712             # remove all tick labels, so only error for > 0 ticklabels
#    1713             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1714                 raise ValueError(
#    1715                     "The number of FixedLocator locations"
#    1716                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (6), usually from a call to set_ticks, does not match the number of ticklabels (4).

# %% [markdown]
# ### Dataset Size 20%

# %%
epsilon = 0.1
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.2, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
print(acc)
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  3000
# 0.342

# %% [markdown]
# ### Dataset Size 30%

# %%
epsilon = 0.1
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.3, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  4500

# %% [markdown]
# ### Dataset Size 40%

# %%
epsilon = 0.1
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.4, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  6000

# %% [markdown]
# ### Dataset Size 50%

# %%
epsilon = 0.1
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.5, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  7500

# %% [markdown]
# ### Dataset Size 60%

# %%
epsilon = 0.1
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.6, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  9000

# %% [markdown]
# ### Dataset Size 70%

# %%
epsilon = 0.1
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.7, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  10500

# %% [markdown]
# ### Dataset Size 80%

# %%
epsilon = 0.1
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.8, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  12000

# %% [markdown]
# ### Dataset Size 90%

# %%
epsilon = 0.1
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.9, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  13500

# %% [markdown]
# ### Dataset Size 100%

# %%
epsilon = 0.1
point = 10

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(features, target)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(target, db.labels_)

print("Train size : ", len(target))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(target, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(target, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  15000

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Dataset Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 11), total_acc, label='TEST set', color='red')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line2 = ax2.plot(range(1, 11), total_time, label='TRAIN time', color='green')

lines = line1 + line2

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()

# %% [markdown]
# ## DBSCAN with PCA feature 2

# %%
total_acc = []
total_time = []

features, target = make_classification(n_samples=15000, n_features=4, n_informative=4, n_redundant=0, n_classes=3, n_clusters_per_class=1, random_state=0)

pca = PCA(n_components=2)
features = pca.fit(features).transform(features)
features = scaler.fit_transform(features)
target_names = ["0", "1", "2", "outlier"]

# %% [markdown]
# ### Dataset Size 10%

# %%
epsilon = 0.05
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.1, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  1500

# %% [markdown]
# ### Dataset Size 20%

# %%
epsilon = 0.05
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.2, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  3000

# %% [markdown]
# ### Dataset Size 30%

# %%
epsilon = 0.05
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.3, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  4500

# %% [markdown]
# ### Dataset Size 40%

# %%
epsilon = 0.05
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.4, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  6000

# %% [markdown]
# ### Dataset Size 50%

# %%
epsilon = 0.05
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.5, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  7500

# %% [markdown]
# ### Dataset Size 60%

# %%
epsilon = 0.05
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.6, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  9000

# %% [markdown]
# ### Dataset Size 70%

# %%
epsilon = 0.05
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.7, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  10500

# %% [markdown]
# ### Dataset Size 80%

# %%
epsilon = 0.05
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.8, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  12000

# %% [markdown]
# ### Dataset Size 90%

# %%
epsilon = 0.05
point = 10

x_train, _, y_train, _ = train_test_split(features, target, train_size=0.9, random_state=0, shuffle=True)

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(x_train, y_train)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(y_train, db.labels_)

print("Train size : ", len(y_train))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(y_train, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(y_train, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  13500

# %% [markdown]
# ### Dataset Size 100%

# %%
epsilon = 0.05
point = 10

db = DBSCAN(eps=epsilon, min_samples=point, n_jobs=-1)

start = time.perf_counter()
db.fit(features, target)
end = time.perf_counter() - start

predict = db.labels_
predict[db.labels_ == -1] = 3

acc = metrics.accuracy_score(target, db.labels_)

print("Train size : ", len(target))
total_acc.append(acc)
total_time.append(end)

cm = confusion_matrix(target, predict, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(target, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= target_names)
disp.plot(cmap=plt.cm.Blues)
# Out:
# Train size :  15000

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Dataset Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 11), total_acc, label='TEST set', color='red')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line2 = ax2.plot(range(1, 11), total_time, label='TRAIN time', color='green')

lines = line1 + line2

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()
