# %% [markdown]
# ## Experimental results by train & test size using Dimension Reduction
#
# 학습 데이터 및 테스트 사이즈에 따른 실험 결과
#
# <span style="color: #2D3748; background-color:#fff5b1;">테스트 사이즈가 점점 증가하고 학습 데이터가 점점 감소하는 경우 정확도는 감소한다. 하지만 분류 시간의 경우 학습 데이터와 테스트 데이터의 비율에 따라 증가하다가 감소한다. PCA를 적용하지 않은 방법과 유사한 형태의 실험 결과를 보여준다.</span>

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.neighbors import NearestCentroid
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## kNN with PCA feature 3

# %%
train_acc = []
test_acc = []
train_time = []

iris = load_iris()

pca = PCA(n_components=3)
features = pca.fit(iris.data).transform(iris.data)
target = iris.target

# %% [markdown]
# ### Test Size 10%

# %%
max_seed = 10

avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.1, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_test_acc.append(test_score)
    avg_time.append(end)

test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 20%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 30%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 40%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 50%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.5, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 60%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.6, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 70%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.7, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 80%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.8, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 90%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.9, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Test Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 10), train_acc, label='TRAIN set')
line2 = ax1.plot(range(1, 10), test_acc, label='TEST set')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line3 = ax2.plot(range(1, 10), train_time, label='TRAIN time', color='green')

lines = line1 + line2 + line3

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()

# %% [markdown]
# ## kNN with PCA feature 2

# %%
train_acc = []
test_acc = []
train_time = []

iris = load_iris()

pca = PCA(n_components=2)
features = pca.fit(iris.data).transform(iris.data)
target = iris.target

# %% [markdown]
# ### Test Size 10%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.1, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 20%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 30%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 40%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 50%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.5, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 60%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.6, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 70%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.7, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 80%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.8, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Test Size 90%

# %%
max_seed = 10

avg_training_acc = []
avg_test_acc = []
avg_time = []

predict_list = []
label_list = []

for seed in range(max_seed):

    x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.9, random_state=seed, shuffle=True)

    k = 1

    knn = KNeighborsClassifier(k, weights='distance', n_jobs=-1)
    knn.fit(x_train, y_train)

    train_score = knn.score(x_train, y_train)
    predict = knn.predict(x_test)

    predict_list.extend(predict)
    label_list.extend(y_test)

    start = time.perf_counter()
    test_score = knn.score(x_test, y_test)
    end = time.perf_counter() - start

    avg_training_acc.append(train_score)
    avg_test_acc.append(test_score)
    avg_time.append(end)

train_avg = np.array(avg_training_acc).mean()
test_avg = np.array(avg_test_acc).mean()
time_avg = np.array(avg_time).mean()

train_acc.append(train_avg)
test_acc.append(test_avg)
train_time.append(time_avg)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_, normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

cm = confusion_matrix(label_list, predict_list, labels=knn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Test Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 10), train_acc, label='TRAIN set')
line2 = ax1.plot(range(1, 10), test_acc, label='TEST set')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line3 = ax2.plot(range(1, 10), train_time, label='TRAIN time', color='green')

lines = line1 + line2 + line3

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()

# %% [markdown]
# ## Nearest Centroid Classifier

# %%
train_acc = []
test_acc = []
train_time = []

iris = load_iris()

# %% [markdown]
# ### Test Size 10%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.1, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=iris.target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  135  / test size :  15
#
# Training set score: 0.925926
# Test set score: 0.866667
# Training Time : 0.0007 sec

# %% [markdown]
# ### Test Size 20%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=iris.target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  120  / test size :  30
#
# Training set score: 0.941667
# Test set score: 0.900000
# Training Time : 0.0004 sec

# %% [markdown]
# ### Test Size 30%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=iris.target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  105  / test size :  45
#
# Training set score: 0.933333
# Test set score: 0.911111
# Training Time : 0.0007 sec

# %% [markdown]
# ### Test Size 40%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=iris.target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  90  / test size :  60
#
# Training set score: 0.922222
# Test set score: 0.866667
# Training Time : 0.0005 sec

# %% [markdown]
# ### Test Size 50%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.5, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=iris.target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  75  / test size :  75
#
# Training set score: 0.933333
# Test set score: 0.866667
# Training Time : 0.0003 sec

# %% [markdown]
# ### Test Size 60%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.6, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=iris.target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  60  / test size :  90
#
# Training set score: 0.933333
# Test set score: 0.877778
# Training Time : 0.0006 sec

# %% [markdown]
# ### Test Size 70%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.7, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=iris.target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  45  / test size :  105
#
# Training set score: 0.933333
# Test set score: 0.885714
# Training Time : 0.0005 sec

# %% [markdown]
# ### Test Size 80%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.8, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=iris.target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  30  / test size :  120
#
# Training set score: 0.933333
# Test set score: 0.891667
# Training Time : 0.0007 sec

# %% [markdown]
# ### Test Size 90%

# %%
seed = 0

x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.9, random_state=seed, shuffle=True)

print("train size : ", len(x_train), " / test size : ", len(x_test))
print()

k = 1

nc = NearestCentroid()
nc.fit(x_train, y_train)

train_score = nc.score(x_train, y_train)

start = time.perf_counter()
test_score = nc.score(x_test, y_test)
end = time.perf_counter() - start

print("Training set score: %f" % train_score)
print("Test set score: %f" % test_score)
print("Training Time : %.4f" % (time.perf_counter() - start), "sec")

train_acc.append(train_score)
test_acc.append(test_score)
train_time.append(end)

disp = ConfusionMatrixDisplay.from_estimator(nc, x_test, y_test, display_labels=iris.target_names, cmap=plt.cm.Blues, normalize="true")
disp.ax_.set_title("Normalized confusion matrix")
plt.show()
# Out:
# train size :  15  / test size :  135
#
# Training set score: 0.933333
# Test set score: 0.896296
# Training Time : 0.0004 sec

# %% [markdown]
# ### Experiment Result

# %%
plt.figure(figsize=(12, 9))

fig, ax1 = plt.subplots()
ax1.set_xlabel("Test Size")
ax1.set_ylabel("Accuracy")
line1 = ax1.plot(range(1, 10), train_acc, label='TRAIN set')
line2 = ax1.plot(range(1, 10), test_acc, label='TEST set')

ax2 = ax1.twinx()
ax2.set_ylabel("Seconds")
line3 = ax2.plot(range(1, 10), train_time, label='TRAIN time', color='green')

lines = line1 + line2 + line3

labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='center right', bbox_to_anchor=(1.5, 0.5))

plt.show()
